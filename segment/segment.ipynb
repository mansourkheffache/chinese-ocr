# %%
# !ls
# Out:
# fragments  fragmentStrip.py  __pycache__  segment.py  Untitled.ipynb

# %%
import glob
from IPython.display import display, Image
import matplotlib.pyplot as plt

# %%
from fragmentStrip import *
#from segment import *
# Out:
# Using TensorFlow backend.

# %%
files = glob.glob("../../Task1/train/*")
files.sort()

# %%
N = 0
files[2*N: 2*N+2]
# Out:
# ['../../Task1/train/004708932_00055_l0.jpg',
#  '../../Task1/train/004708932_00055_l0.txt']

# %%
N = 4
file = files[2*N: 2*N+2][0]

display(Image(file))

# %%
N = 4
file = files[2*N: 2*N+2][0]

fragmentStrip(file, "fragments", quantile = 0.95)
# Out:
# Image size: (143, 1599)
# Image size: (143, 1599)
# <PIL.Image.Image image mode=L size=133x362 at 0x7F95F485D400>
# <PIL.Image.Image image mode=L size=133x94 at 0x7F95F485D400>
# <PIL.Image.Image image mode=L size=133x96 at 0x7F95F485D400>
# <PIL.Image.Image image mode=L size=133x93 at 0x7F95F484DB38>
# <PIL.Image.Image image mode=L size=133x90 at 0x7F95F484DB38>
# <PIL.Image.Image image mode=L size=133x94 at 0x7F95F484DB38>
# <PIL.Image.Image image mode=L size=133x100 at 0x7F95F484DB38>
# <PIL.Image.Image image mode=L size=133x306 at 0x7F95F484DB38>
# <PIL.Image.Image image mode=L size=133x91 at 0x7F95F484DB38>
# <PIL.Image.Image image mode=L size=133x97 at 0x7F95F484DB38>
# <PIL.Image.Image image mode=L size=133x95 at 0x7F95F484DB38>
